# %%
# Import candidate models
from doubt import Boot, QuantileRegressor, QuantileRegressionForest
from sklearn.linear_model import (LinearRegression, PoissonRegressor, 
                                  GammaRegressor, HuberRegressor)
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import LinearSVR
from sklearn.neural_network import MLPRegressor

# Import datasets
from doubt.datasets import (Airfoil, Blog, Concrete, CPU, 
                            FacebookComments, FishBioconcentration,
                            FishToxicity, ForestFire, NewTaipeiHousing,
                            PowerPlant, Protein, Servo,
                            SpaceShuttle, Yacht)

# Import external libraries
import pandas as pd
import numpy as np
from tqdm.auto import tqdm, trange
from scipy.stats import ks_2samp, entropy, kruskal
import matplotlib.pyplot as plt; plt.style.use('ggplot')
from sklearn.preprocessing import StandardScaler
import warnings
from collections import defaultdict

# Import internal classes
from distributions import DistributionShift
from src.psi import psi

# %%
from xgboost import XGBRegressor

# %%
dataset_classes = [Airfoil, Concrete,
                   FishToxicity, ForestFire, NewTaipeiHousing,
                   PowerPlant, Protein, Servo]

# %%
def monitoring_plot(dataset, base_regressor: type):
    
    with warnings.catch_warnings():
        warnings.simplefilter('ignore')
        
        # Initialise the scaler
        standard_scaler = StandardScaler()
        
        # Load the dataset and split it
        X_train, X_test, y_train, y_test = dataset().split(test_size=0.3, random_seed=4242)
        
        # Scale the dataset
        X_train = standard_scaler.fit_transform(X_train)
        X_test = standard_scaler.transform(X_test)

        # Initialise the shifter
        shifter = DistributionShift()
        shifter.fit(X_train)

        def initialise_plot(num_rows: int, num_cols: int):
            fig, axs = plt.subplots(num_rows, num_cols, sharex=True, sharey=True, figsize=(14, 3.5 * num_rows))
            fig.suptitle(f'Monitoring plot for the {dataset.__name__} dataset under feature drift with {base_regressor.__name__}', fontsize=16)
            for j in range(num_cols):
                axs[num_rows - 1, j].set_xlabel('Number of standard deviations shifted')
            for i in range(num_rows):
                axs[i, 0].set_ylabel('Normalised values')
            return fig, axs

        # Fit the regressor
        regressor = Boot(base_regressor())
        regressor.fit(X_train, y_train, n_boots=20)

        xx = np.arange(-10, 11, 1.0)
        num_rows = X_train.shape[1] // 3
        if X_train.shape[1] % 3 > 0:
            num_rows += 1
        fig, axs = initialise_plot(num_rows=num_rows, num_cols=3)
        for idx, col in enumerate(trange(X_train.shape[1])):
            values = defaultdict(list)
            for std in xx:
                shifter.set_params(param=std, cols=[col])
                new_X_test = shifter.transform(X_test)

                predictions, intervals = regressor.predict(new_X_test, uncertainty=0.05, n_boots=20)

                values['uncertainty'].append(np.mean(intervals[:, 1] - intervals[:, 0]))
                values['psi'].append(sum(psi(X_train[:, c], new_X_test[:, c]) for c in range(X_train.shape[1])))
                values['ks'].append(sum(ks_2samp(X_train[:, c], new_X_test[:, c]).statistic for c in range(X_train.shape[1])))
                values['mse'].append(np.mean((predictions - y_test) ** 2))

            # Normalise the values
            for name, vals in values.items():
                values[name] = standard_scaler.fit_transform(np.expand_dims(vals, -1))

            for name, vals in values.items():
                if idx == 0:
                    axs[idx // 3, idx % 3].plot(xx, vals, marker='x', label=f'{name} values')
                else:
                    axs[idx // 3, idx % 3].plot(xx, vals, marker='x')

        fig.legend()
        plt.savefig('fig.png')
        plt.show()

# %%
# %%time
for dataset in dataset_classes:
    monitoring_plot(dataset, XGBRegressor)
# Out:
#   0%|          | 0/5 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <timed exec> in <module>
#
# <ipython-input-4-de34d9f69f4c> in monitoring_plot(dataset, base_regressor)
#      42                 new_X_test = shifter.transform(X_test)
#      43
# ---> 44                 predictions, intervals = regressor.predict(new_X_test, uncertainty=0.05, n_boots=20)
#      45
#      46                 values['uncertainty'].append(np.mean(intervals[:, 1] - intervals[:, 0]))
#
# ~/opt/anaconda3/envs/uncertainty/lib/python3.7/site-packages/doubt/models/boot/boot.py in predict(self, X, n_boots, uncertainty, quantiles)
#     274         y_train = self.y_train[train_idxs]
#     275
# --> 276         bootstrap_pred = self._model_fit_predict(X_train, y_train, X)
#     277         bootstrap_preds[boot_idx] = bootstrap_pred
#     278
#
# ~/opt/anaconda3/envs/uncertainty/lib/python3.7/site-packages/doubt/models/boot/boot.py in _model_fit_predict(self, X_train, y_train, X_test)
#     114     '''
#     115     model = copy.deepcopy(self._model)
# --> 116     model.fit(X_train, y_train)
#     117     if callable(model):
#     118         return model(X_test)
#
# ~/opt/anaconda3/envs/uncertainty/lib/python3.7/site-packages/xgboost/core.py in inner_f(*args, **kwargs)
#     434         for k, arg in zip(sig.parameters, args):
#     435             kwargs[k] = arg
# --> 436         return f(**kwargs)
#     437
#     438     return inner_f
#
# ~/opt/anaconda3/envs/uncertainty/lib/python3.7/site-packages/xgboost/sklearn.py in fit(self, X, y, sample_weight, base_margin, eval_set, eval_metric, early_stopping_rounds, verbose, xgb_model, sample_weight_eval_set, base_margin_eval_set, feature_weights, callbacks)
#     745             verbose_eval=verbose,
#     746             xgb_model=model,
# --> 747             callbacks=callbacks,
#     748         )
#     749
#
# ~/opt/anaconda3/envs/uncertainty/lib/python3.7/site-packages/xgboost/training.py in train(params, dtrain, num_boost_round, evals, obj, feval, maximize, early_stopping_rounds, evals_result, verbose_eval, xgb_model, callbacks)
#     195                           evals_result=evals_result,
#     196                           maximize=maximize,
# --> 197                           early_stopping_rounds=early_stopping_rounds)
#     198     return bst
#     199
#
# ~/opt/anaconda3/envs/uncertainty/lib/python3.7/site-packages/xgboost/training.py in _train_internal(params, dtrain, num_boost_round, evals, obj, feval, xgb_model, callbacks, evals_result, maximize, verbose_eval, early_stopping_rounds)
#     108     # Copy to serialise and unserialise booster to reset state and free
#     109     # training memory
# --> 110     return bst.copy()
#     111
#     112
#
# ~/opt/anaconda3/envs/uncertainty/lib/python3.7/site-packages/xgboost/core.py in copy(self)
#    1349             a copied booster model
#    1350         """
# -> 1351         return self.__copy__()
#    1352
#    1353     def attr(self, key):
#
# ~/opt/anaconda3/envs/uncertainty/lib/python3.7/site-packages/xgboost/core.py in __copy__(self)
#    1335
#    1336     def __copy__(self):
# -> 1337         return self.__deepcopy__(None)
#    1338
#    1339     def __deepcopy__(self, _):
#
# ~/opt/anaconda3/envs/uncertainty/lib/python3.7/site-packages/xgboost/core.py in __deepcopy__(self, _)
#    1339     def __deepcopy__(self, _):
#    1340         '''Return a copy of booster.'''
# -> 1341         return Booster(model_file=self)
#    1342
#    1343     def copy(self):
#
# ~/opt/anaconda3/envs/uncertainty/lib/python3.7/site-packages/xgboost/core.py in __init__(self, params, cache, model_file)
#    1211             # We use the pickle interface for getting memory snapshot from
#    1212             # another model, and load the snapshot with this booster.
# -> 1213             state = model_file.__getstate__()
#    1214             handle = state['handle']
#    1215             del state['handle']
#
# ~/opt/anaconda3/envs/uncertainty/lib/python3.7/site-packages/xgboost/core.py in __getstate__(self)
#    1251             _check_call(_LIB.XGBoosterSerializeToBuffer(self.handle,
#    1252                                                         ctypes.byref(length),
# -> 1253                                                         ctypes.byref(cptr)))
#    1254             buf = ctypes2buffer(cptr, length.value)
#    1255             this["handle"] = buf
#
# KeyboardInterrupt:

# %%
# %%time
for dataset in dataset_classes:
    monitoring_plot(dataset, PoissonRegressor)

# %%
# %%time
for dataset in dataset_classes:
    monitoring_plot(dataset, GammaRegressor)

# %%
# %%time
for dataset in dataset_classes:
    monitoring_plot(dataset, MLPRegressor)
